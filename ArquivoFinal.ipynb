# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt-get install time -y
# %cd /content/drive/MyDrive/projeto
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# time is already the newest version (1.9-0.1build2).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# /content/drive/MyDrive/projeto

# %%
# !g++ -pthread main.cpp -o programa # Versão sem as otimizações de compilador
# Out:
# /content/projeto

# %%
# !g++ -O3 -pthread main.cpp -o programa # Versão com as otimizações de compilador

# %%
# !/usr/bin/time -v ./programa
# Out:
# Iniciando leitura paralela (com byte chunking)
# Lendo o cabecalho e inferindo tipos
# Leitura concluida. Fundindo todos os dicionarios locais das threads
# Dicionarios fundidos com sucesso! Limpando cabecalhos...
#
# ----------------RELATORIO ESTATISTICO----------------
#
# [Numerica] idatracacao:
#  - Minimo:        735424
#  - Maximo:        1.06458e+06
#  - Media:         909254
#  - Variancia:     6.82926e+09
#  - Desvio Padrao: 82639.3
#  - Moda:          924217
#  - Mediana:       913237
#  - IQR:           136164
#
# [Categorica] cdtup:
# Moda: BRSSZ (ID: 10)
#
# [Categorica] berco:
# Moda: EXTERNO (ID: 135)
#
# [Categorica] portoatracacao:
# Moda: Santos (ID: 10)
#
# [Numerica] ano:
#  - Minimo:        2016
#  - Maximo:        2019
#  - Media:         2017.58
#  - Variancia:     1.20277
#  - Desvio Padrao: 1.09671
#  - Moda:          2018
#  - Mediana:       2018
#  - IQR:           2
#
# [Categorica] mes:
# Moda: ago (ID: 0)
#
# [Categorica] tipooperacao:
# ...
